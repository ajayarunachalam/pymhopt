# %%
import pandas as pd
import numpy as np
data = pd.read_csv('dataset_Facebook.csv', sep=';')
print(data.shape)
# Out:
# (500, 19)

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# 3                    2211                      790
# 4                     671                      410
#
#    Lifetime Post Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
# 4                                               6228
#
#    Lifetime Post reach by people who like your Page  \
# 0                                              1640
# 1                                              6112
# 2                                              1503
# 3                                             32048
# 4                                              3200
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                                119
# 1                                               1108
# 2                                                132
# 3                                               1386
# 4                                                396
#
#    comment    like  share  Total Interactions
# 0        4    79.0   17.0                 100
# 1        5   130.0   29.0                 164
# 2        0    66.0   14.0                  80
# 3       58  1572.0  147.0                1777
# 4       19   325.0   49.0                 393

# %%
from pyOP.optimization import *

# %%
data_fb, df_fb = Optimization.read_data(data)

# %%
data_fb.shape, df_fb.shape
# Out:
# ((500, 19), (500, 19))

# %%
def missing(x):
    return sum(x.isnull())

# %%
print("Checking for Missing row & col wise")
print('**************************')
print("Missing values per row:")
print(df_fb.apply(missing, axis=1))
print("Missing values per column:")
print(df_fb.apply(missing, axis=0))
# Out:
# Checking for Missing row & col wise
# **************************
# Missing values per row:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 495    0
# 496    0
# 497    0
# 498    0
# 499    0
# Length: 500, dtype: int64
# Missing values per column:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# Lifetime Post reach by people who like your Page                       0
# Lifetime People who have liked your Page and engaged with your post    0
# comment                                                                0
# like                                                                   0
# share                                                                  0
# Total Interactions                                                     0
# dtype: int64

# %%
NUM_FEATURES, SELECTED_FEATURES, OPTIMIZATION_TARGET, CATEGORICAL_SELECT, NUM_GENERATIONS = Optimization.set_config(NUM_FEATURES=18, SELECTED_FEATURES=['Category', 'Type', 'Post Month', 'Post Weekday', 'Post Hour', 'Paid'], OPTIMIZATION_TARGET='Total Interactions',  CATEGORICAL_SELECT=['Category', 'Type', 'Paid'],
                                                                                                 NUM_GENERATIONS=20)
# Out:
# NUM_FEATURES = 18
# SELECTED_FEATURES = ['Category', 'Type', 'Post Month', 'Post Weekday', 'Post Hour', 'Paid']
# OPTIMIZATION_TARGET = Total Interactions
# CATEGORICAL_SELECT = ['Category', 'Type', 'Paid']
# NUM_GENERATIONS = 20

# %%
Optimization.symbolic(df=data_fb, selected_features=SELECTED_FEATURES, target=OPTIMIZATION_TARGET, categorical_cols=CATEGORICAL_SELECT,generations=NUM_GENERATIONS)
# Out:
# C:\Users\OruStandalone\Anaconda3\lib\site-packages\pandas\core\indexing.py:1715: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, v)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Training Model sr
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#    0    23.79          228.723       31          149.851          172.619     10.73s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#    1    20.43          194.542       29          140.748          193.655      9.84s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#    2    39.04          198.351       45          127.027          207.354     11.17s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#    3    45.73          209.897       61          129.287          203.414     11.04s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#    4    43.06          186.792      139          129.596          198.264      9.83s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#    5    45.40          198.848      137          122.715          215.077      9.49s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#    6    53.17          195.271       33          128.443          192.558      9.54s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#    7    57.63          207.596       31          127.641          210.301      9.07s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#    8    73.13          197.281       57          121.085          213.767      9.38s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#    9    81.01          215.217       41          121.225          226.168      9.17s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#   10    75.76          196.032       63          124.959          205.555      7.69s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#   11    78.91          345.373      113          118.692          222.283      7.13s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#   12    84.36          205.254       31          126.345          199.712      6.35s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#   13    83.11          237.368       83          122.019          207.177      5.42s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#   14    83.83          223.614       43          122.872          211.168      4.54s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#   15    95.10          178.423      163          121.905          205.301      3.82s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#   16   109.38          201.125       97          123.311          201.586      3.18s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#   17   122.56          186.319       65          115.375            220.1      2.24s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#   18   117.34           173.44       71          116.588          214.451      1.09s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s finished
#   19   102.85          211.038      263          117.903          227.804      0.00s
# Training Model lm
# Training Model rf
# Model sr:
#  MAE: 198.24858640566623
#  MSE: 382611.40267258696
#
# Model lm:
#  MAE: 195.50896358729676
#  MSE: 345445.36320583284
#
# Model rf:
#  MAE: 206.62829428571428
#  MSE: 360726.0476522471
#
# add(div(add(div(add(div(X11, X5), add(X11, 0.441)), mul(X6, X8)), sub(sub(div(X8, X4), add(sub(X7, sub(sub(div(X8, X4), add(X10, 0.197)), div(sub(X5, 0.108), sub(X5, X3)))), mul(X11, X3))), div(sub(X5, 0.108), sub(X5, X3)))), sub(div(sub(add(-0.597, X8), add(X3, X6)), add(sub(add(mul(X0, add(sub(X0, X7), add(X11, X6))), div(add(mul(X1, X11), add(mul(mul(X1, X8), add(div(X8, X4), div(div(X2, X5), div(X2, X2)))), add(mul(mul(X1, X8), add(X11, X8)), sub(X8, X11)))), mul(sub(X11, X5), sub(X10, X10)))), X9), sub(0.306, X6))), sub(0.306, X6))), sub(div(mul(mul(div(X2, X6), sub(X7, div(div(X1, X7), add(-0.143, X7)))), sub(div(X2, X5), div(X5, X11))), div(mul(mul(div(X10, X2), X10), mul(X1, X9)), sub(div(mul(mul(div(X2, X6), sub(X7, X8)), sub(mul(mul(X1, sub(X9, X5)), mul(sub(X7, X2), div(X9, X4))), div(X5, X11))), div(mul(div(X8, X8), mul(X1, X9)), add(add(add(-0.597, X8), sub(X8, X11)), add(X0, X5)))), mul(div(X2, X6), sub(X7, X8))))), add(add(div(div(X1, X7), add(-0.143, X7)), sub(div(X0, X8), sub(add(mul(X0, add(sub(X0, X7), mul(X6, X8))), div(add(mul(X1, X11), mul(X6, X8)), mul(mul(add(X7, X1), sub(X9, X5)), mul(sub(X7, X2), div(X9, X4))))), X9))), mul(mul(add(X1, X4), sub(X6, X2)), sub(add(X9, X10), sub(-0.965, X5))))))
# FITTEST SOLUTION WITH FEATURES: add(div(add(div(add(div(Paid_1.0, Category_3), add(Paid_1.0, 0.441)), mul(Type_Link, Type_Status)), sub(sub(div(Type_Status, Category_2), add(sub(Type_Photo, sub(sub(div(Type_Status, Category_2), add(Paid_0.0, 0.197)), div(sub(Category_3, 0.108), sub(Category_3, Category_1)))), mul(Paid_1.0, Category_1))), div(sub(Category_3, 0.108), sub(Category_3, Category_1)))), sub(div(sub(add(-0.597, Type_Status), add(Category_1, Type_Link)), add(sub(add(mul(Post Month, add(sub(Post Month, Type_Photo), add(Paid_1.0, Type_Link))), div(add(mul(Post Weekday, Paid_1.0), add(mul(mul(Post Weekday, Type_Status), add(div(Type_Status, Category_2), div(div(Post Hour, Category_3), div(Post Hour, Post Hour)))), add(mul(mul(Post Weekday, Type_Status), add(Paid_1.0, Type_Status)), sub(Type_Status, Paid_1.0)))), mul(sub(Paid_1.0, Category_3), sub(Paid_0.0, Paid_0.0)))), Type_Video), sub(0.306, Type_Link))), sub(0.306, Type_Link))), sub(div(mul(mul(div(Post Hour, Type_Link), sub(Type_Photo, div(div(Post Weekday, Type_Photo), add(-0.143, Type_Photo)))), sub(div(Post Hour, Category_3), div(Category_3, Paid_1.0))), div(mul(mul(div(Paid_0.0, Post Hour), Paid_0.0), mul(Post Weekday, Type_Video)), sub(div(mul(mul(div(Post Hour, Type_Link), sub(Type_Photo, Type_Status)), sub(mul(mul(Post Weekday, sub(Type_Video, Category_3)), mul(sub(Type_Photo, Post Hour), div(Type_Video, Category_2))), div(Category_3, Paid_1.0))), div(mul(div(Type_Status, Type_Status), mul(Post Weekday, Type_Video)), add(add(add(-0.597, Type_Status), sub(Type_Status, Paid_1.0)), add(Post Month, Category_3)))), mul(div(Post Hour, Type_Link), sub(Type_Photo, Type_Status))))), add(add(div(div(Post Weekday, Type_Photo), add(-0.143, Type_Photo)), sub(div(Post Month, Type_Status), sub(add(mul(Post Month, add(sub(Post Month, Type_Photo), mul(Type_Link, Type_Status))), div(add(mul(Post Weekday, Paid_1.0), mul(Type_Link, Type_Status)), mul(mul(add(Type_Photo, Post Weekday), sub(Type_Video, Category_3)), mul(sub(Type_Photo, Post Hour), div(Type_Video, Category_2))))), Type_Video))), mul(mul(add(Post Weekday, Category_2), sub(Type_Link, Post Hour)), sub(add(Type_Video, Paid_0.0), sub(-0.965, Category_3))))))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     169     try:
# --> 170         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     171     except OSError as e:
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#
# ~\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#     996                                          os.fspath(cwd) if cwd is not None else None,
# --> 997                                          startupinfo)
#     998             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-9-13b51ca4f9cc> in <module>()
# ----> 1 Optimization.symbolic(df=data_fb, selected_features=SELECTED_FEATURES, target=OPTIMIZATION_TARGET, categorical_cols=CATEGORICAL_SELECT,generations=NUM_GENERATIONS)
#
# F:\package_my_py\pymhopt\pyOP\optimization.py in symbolic(df, selected_features, target, categorical_cols, generations)
#     114         # Save on disk
#     115         src = graphviz.Source(graph_str)
# --> 116         src.render('./result.gv', view=True)
#     117
#     118     def nsgaII(df, selected_features=SELECTED_FEATURES, target=OPTIMIZATION_TARGET, categorical_cols = None, max_generations=NUM_GENERATIONS):
#
# ~\Anaconda3\lib\site-packages\graphviz\files.py in render(self, filename, directory, view, cleanup, format, renderer, formatter, quiet, quiet_view)
#     238         rendered = backend.render(self._engine, format, filepath,
#     239                                   renderer=renderer, formatter=formatter,
# --> 240                                   quiet=quiet)
#     241
#     242         if cleanup:
#
# ~\Anaconda3\lib\site-packages\graphviz\backend.py in render(***failed resolving arguments***)
#     233         cwd = None
#     234
# --> 235     run(cmd, capture_output=True, cwd=cwd, check=True, quiet=quiet)
#     236     return rendered
#     237
#
# ~\Anaconda3\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     171     except OSError as e:
#     172         if e.errno == errno.ENOENT:
# --> 173             raise ExecutableNotFound(cmd) from e
#     174         else:
#     175             raise
#
# ExecutableNotFound: failed to execute 'dot', make sure the Graphviz executables are on your systems' PATH

# %%
Optimization.nsgaII(df=data_fb, selected_features=SELECTED_FEATURES, target=OPTIMIZATION_TARGET, categorical_cols=CATEGORICAL_SELECT, max_generations=20)
# Out:
# C:\Users\OruStandalone\Anaconda3\lib\site-packages\pandas\core\indexing.py:1715: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, v)
# g: 1 elite obj1: 90117.578 , size: 9
# g: 2 elite obj1: 89478.222 , size: 8
# g: 3 elite obj1: 89478.222 , size: 8
# g: 4 elite obj1: 89478.222 , size: 8
# g: 5 elite obj1: 89478.222 , size: 8
# g: 6 elite obj1: 88975.749 , size: 7
# g: 7 elite obj1: 87387.935 , size: 17
# g: 8 elite obj1: 85778.989 , size: 22
# g: 9 elite obj1: 83942.793 , size: 9
# g: 10 elite obj1: 83942.793 , size: 9
# g: 11 elite obj1: 83942.793 , size: 9
# g: 12 elite obj1: 83942.793 , size: 9
# g: 13 elite obj1: 83120.998 , size: 13
# g: 14 elite obj1: 83120.998 , size: 13
# g: 15 elite obj1: 82610.074 , size: 15
# g: 16 elite obj1: 82610.061 , size: 13
# g: 17 elite obj1: 82610.061 , size: 13
# g: 18 elite obj1: 82610.061 , size: 13
# g: 19 elite obj1: 82610.061 , size: 15
# g: 20 elite obj1: 82610.061 , size: 15
# Terminating at
# 	 20 generations
# 	 9324 evaluations
# 	 29.54 seconds
# len front: 666
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x2 / ( x3 + x10 ) ) / x1 )
# ( ( x2 / ( x3 + x10 ) ) / x1 )
# ( ( x2 / ( x3 + x10 ) ) / x1 )
# ( ( x2 / ( x3 + x10 ) ) / x1 )
# ( ( x2 / ( x3 + x10 ) ) / x1 )
# ( ( ( x2 / ( x3 + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( x3 + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x1 ) / x3 ) / x1 )
# ( ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 ) / x1 )
# ( ( ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x1 ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x1 ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x2 / ( x3 + x10 ) ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x1 ) / x3 ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x1 ) / x3 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( x3 + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( x3 + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( ( x2 / ( ( x3 + x3 ) + x10 ) ) / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# ( ( x11 / x3 ) / x1 )
# g: 1 elite obj1: 145966.153 , size: 43
# g: 2 elite obj1: 128840.464 , size: 46
# g: 3 elite obj1: 127759.973 , size: 43
# g: 4 elite obj1: 127759.973 , size: 43
# g: 5 elite obj1: 126808.348 , size: 49
# g: 6 elite obj1: 111311.783 , size: 44
# g: 7 elite obj1: 111311.783 , size: 44
# g: 8 elite obj1: 111311.783 , size: 44
# g: 9 elite obj1: 111311.783 , size: 44
# g: 10 elite obj1: 111311.783 , size: 44
# g: 11 elite obj1: 111311.783 , size: 44
# g: 12 elite obj1: 107615.752 , size: 31
# g: 13 elite obj1: 107615.752 , size: 31
# g: 14 elite obj1: 107615.752 , size: 31
# g: 15 elite obj1: 93769.849 , size: 39
# g: 16 elite obj1: 93769.849 , size: 39
# g: 17 elite obj1: 89164.601 , size: 38
# g: 18 elite obj1: 89164.601 , size: 38
# g: 19 elite obj1: 89164.601 , size: 38
# g: 20 elite obj1: 89164.601 , size: 38
# Terminating at
# 	 20 generations
# 	 9476 evaluations
# 	 31.36 seconds
# g: 1 elite obj1: 146234.104 , size: 49
# g: 2 elite obj1: 143071.315 , size: 11
# g: 3 elite obj1: 142438.706 , size: 15
# g: 4 elite obj1: 141239.62 , size: 7
# g: 5 elite obj1: 139457.921 , size: 8
# g: 6 elite obj1: 139457.921 , size: 8
# g: 7 elite obj1: 132991.625 , size: 43
# g: 8 elite obj1: 132991.625 , size: 43
# g: 9 elite obj1: 115798.974 , size: 15
# g: 10 elite obj1: 115798.974 , size: 15
# g: 11 elite obj1: 57950.715 , size: 15
# g: 12 elite obj1: 57950.715 , size: 15
# g: 13 elite obj1: 57950.715 , size: 15
# g: 14 elite obj1: 57950.715 , size: 15
# g: 15 elite obj1: 57950.715 , size: 15
# g: 16 elite obj1: 57788.25 , size: 17
# g: 17 elite obj1: 57788.25 , size: 17
# g: 18 elite obj1: 57788.25 , size: 17
# g: 19 elite obj1: 57788.25 , size: 17
# g: 20 elite obj1: 57788.25 , size: 17
# Terminating at
# 	 20 generations
# 	 9338 evaluations
# 	 30.34 seconds
# g: 1 elite obj1: 74175.036 , size: 18
# g: 2 elite obj1: 74175.036 , size: 18
# g: 3 elite obj1: 74175.036 , size: 18
# g: 4 elite obj1: 73800.74 , size: 25
# g: 5 elite obj1: 73295.743 , size: 25
# g: 6 elite obj1: 73076.058 , size: 9
# g: 7 elite obj1: 71186.714 , size: 22
# g: 8 elite obj1: 71186.714 , size: 22
# g: 9 elite obj1: 71186.714 , size: 22
# g: 10 elite obj1: 71186.714 , size: 22
# g: 11 elite obj1: 69523.284 , size: 33
# g: 12 elite obj1: 69523.284 , size: 33
# g: 13 elite obj1: 69523.284 , size: 33
# g: 14 elite obj1: 69149.536 , size: 31
# g: 15 elite obj1: 69149.536 , size: 31
# g: 16 elite obj1: 68910.157 , size: 30
# g: 17 elite obj1: 68910.157 , size: 30
# g: 18 elite obj1: 68910.157 , size: 30
# g: 19 elite obj1: 68910.157 , size: 30
# g: 20 elite obj1: 68910.157 , size: 30
# Terminating at
# 	 20 generations
# 	 9264 evaluations
# 	 29.89 seconds
# g: 1 elite obj1: 146896.188 , size: 13
# g: 2 elite obj1: 146896.188 , size: 13
# g: 3 elite obj1: 146896.188 , size: 13
# g: 4 elite obj1: 146653.018 , size: 12
# g: 5 elite obj1: 146653.018 , size: 12
# g: 6 elite obj1: 146417.179 , size: 31
# g: 7 elite obj1: 132592.965 , size: 12
# g: 8 elite obj1: 132592.965 , size: 12
# g: 9 elite obj1: 132592.944 , size: 18
# g: 10 elite obj1: 132592.944 , size: 18
# g: 11 elite obj1: 132433.673 , size: 14
# g: 12 elite obj1: 132433.673 , size: 14
# g: 13 elite obj1: 119295.797 , size: 18
# g: 14 elite obj1: 119295.797 , size: 18
# g: 15 elite obj1: 112846.728 , size: 24
# g: 16 elite obj1: 112846.728 , size: 24
# g: 17 elite obj1: 112846.728 , size: 24
# g: 18 elite obj1: 111702.302 , size: 17
# g: 19 elite obj1: 110498.285 , size: 23
# g: 20 elite obj1: 102124.885 , size: 17
# Terminating at
# 	 20 generations
# 	 9394 evaluations
# 	 29.42 seconds
# g: 1 elite obj1: 158917.931 , size: 60
# g: 2 elite obj1: 156445.902 , size: 19
# g: 3 elite obj1: 156445.902 , size: 19
# g: 4 elite obj1: 156445.902 , size: 19
# g: 5 elite obj1: 141443.611 , size: 29
# g: 6 elite obj1: 140965.264 , size: 33
# g: 7 elite obj1: 140693.68 , size: 27
# g: 8 elite obj1: 140243.916 , size: 36
# g: 9 elite obj1: 140168.911 , size: 23
# g: 10 elite obj1: 139731.635 , size: 31
# g: 11 elite obj1: 122634.688 , size: 36
# g: 12 elite obj1: 122634.688 , size: 36
# g: 13 elite obj1: 122622.244 , size: 36
# g: 14 elite obj1: 122622.244 , size: 36
# g: 15 elite obj1: 122610.414 , size: 35
# g: 16 elite obj1: 122544.644 , size: 47
# g: 17 elite obj1: 122526.353 , size: 43
# g: 18 elite obj1: 122526.353 , size: 43
# g: 19 elite obj1: 121496.652 , size: 11
# g: 20 elite obj1: 121496.652 , size: 11
# Terminating at
# 	 20 generations
# 	 9387 evaluations
# 	 33.99 seconds
# Cross Validation Result: {'fit_time': array([31.36030626, 30.34467387, 29.89094639, 29.41750622, 33.98766184]), 'score_time': array([0.00200152, 0.00103307, 0.0010035 , 0.00199962, 0.00201559]), 'test_score': array([  -47551.97489307, -1383326.92318271,  -419346.84712803,
#         -106070.99275242,   -47321.68647789])}
